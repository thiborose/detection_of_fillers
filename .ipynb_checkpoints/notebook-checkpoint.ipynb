# %% [markdown]
# # Download the corpus

# %%
from os import system
import glob

# %%
# Downloading the audios
#system("wget --accept wav --mirror --no-parent https://media.talkbank.org/ca/CallHome/eng/0wav/ -P ./corpus/original_audio/")
for filename in glob.iglob('./corpus/original_audio/media.talkbank.org/ca/CallHome/eng/0wav/*.wav'):
    _id = filename.split('/')[-1]
    system('mv {} ./corpus/original_audio/{}'.format(filename,_id))
system('rm -r ./corpus/original_audio/media.talkbank.org')

# %%
# Downloading the transcripts
system('wget https://ca.talkbank.org/data/CallHome/eng.zip -P ./corpus/original_text/')
system('unzip -j ./corpus/original_text/eng.zip -d ./corpus/original_text/')
for filename in glob.iglob('./corpus/original_text/*'):
    if not filename.endswith('.cha'):
        system('rm {}'.format(filename))

# %% [markdown]
# # Sentence level alignment

# %%
from os import walk, listdir
from pydub import AudioSegment
import re
import soundfile as sf

# %%
speechs = {}

class Speech():
    def __init__(self, identifier):
        self._id = identifier
        self.audio_path = './corpus/original_audio/'+identifier+'.wav'
        self.transc_path = './corpus/original_text/'+identifier+'.cha'
        self.sentences = [] #dictionnaries like {start (ms), end, text}

# %%
# creating instances
for filename in listdir('./corpus/original_audio/'):
        if filename.endswith('.wav'):
            _id = filename.split('.')[0]
            speechs[_id] = Speech(_id)

# %%
def get_clean_lines(content):
        try:
            content = re.split('@Media.*audio\n',content)[1]
        except:
            return 
        content = re.split('\n@End\n',content)[0]
        lines = re.split('(\x15.*\x15)', content)
        lines2 = []
        i = 0
        pattern = re.compile('\x15.*\x15')
        while i<len(lines):
            elem = lines[i]
            while not pattern.match(lines[i]) and i!=len(lines)-1: #tant ne contient pas (ou n'est pas) un timestamp:
                i += 1
                next_elem = lines[i]
                next_elem = next_elem.replace('*B:', ' ')
                next_elem = next_elem.replace('*A:', ' ')
                elem = elem + ' ' + next_elem #on concatenate avec l'élement suivant
            #quand on tombe sur un timestamp
            elem = elem.replace('\n\t', ' ')
            elem = elem.replace('\n', '')
            elem = elem.replace('\t','')
            elem = elem.replace('*A:',' ')
            elem = elem.replace('*B:',' ')
            elem= elem[1:]
            
            lines2.append(elem)
            i += 1 
    
        lines2 = lines2[:-1]
        return lines2

# %%
# Spotting the sentences
for speech in speechs.values():
        with open(speech.transc_path) as transc_file:
            content = transc_file.read()
            
        #splitting after each timestamp
        lines= get_clean_lines(content)
        if lines == None:
            continue
        
        for i in range(len(lines)):
            lines[i] = lines[i].rstrip()
        for line in lines:
            try:
                timestamp = re.search("\x15(.*)\x15", line).group(1)
            except:
                breakpoint()
            start = int(timestamp.split("_")[0])
            end = int(timestamp.split("_")[1])
            #breakpoint()
            text = re.search("(.*)\x15{}".format(timestamp),line).group(1)
            #writing in the speech object
            speech.sentences.append({'start':start,'end':end, 'text':text})
print("Sentences retrieved")
# Out:
# Sentences retrieved

# %%
# Creating files
for speech in speechs.values():
        print('Cutting {}'.format(speech.audio_path))
        data, samplerate = sf.read(speech.audio_path)
        for sent in speech.sentences:
            title = "{}_{}_{}".format(speech._id, sent['start'], sent['end'])
            cut = data[sent['start']*int((samplerate/1000)):sent['end']*int((samplerate/1000))]
            sf.write('./corpus/alignment/sentence_level_audio/{}.wav'.format(title),cut , samplerate)
            with open('./corpus/alignment/sentence_level_text/{}.txt'.format(title),'w') as outfile:
                print(sent['text'], file = outfile)
# Out:
# Cutting ./corpus/original_audio/4074.wav
# Cutting ./corpus/original_audio/0638.wav
# Cutting ./corpus/original_audio/4065.wav

# %% [markdown]
# # Filtering non-filler utterances

# %%
pattern = re.compile('(mhm|uhhuh|mm|um|eh|em|ah|huh|ha|er|oof|hee|ach|eee|ew)')

for file in glob.iglob('./corpus/alignment/sentence_level_text/*.txt'):
    print(file)
    filename = file.split('/')[-1]
    filename = filename.split('.')[0]
    has_filler = False
    with open(file,'r', encoding = 'utf-8') as infile:
        content = infile.read()
        matched = re.match(pattern, content)
        has_filler = bool(matched)
    if not has_filler:
        print("removing {}".format(file))
        system('rm {}'.format(file))
        system('rm ./corpus/alignment/sentence_level_audio/{}.wav'.format(filename))
# Out:
# ./corpus/alignment/sentence_level_text/0638_660420_661490.txt
# removing ./corpus/alignment/sentence_level_text/0638_660420_661490.txt
# ./corpus/alignment/sentence_level_text/4065_877800_877990.txt
# removing ./corpus/alignment/sentence_level_text/4065_877800_877990.txt
# ./corpus/alignment/sentence_level_text/0638_633020_633590.txt
# removing ./corpus/alignment/sentence_level_text/0638_633020_633590.txt
# ./corpus/alignment/sentence_level_text/4065_1003140_1003450.txt
# removing ./corpus/alignment/sentence_level_text/4065_1003140_1003450.txt
# ./corpus/alignment/sentence_level_text/0638_648960_650930.txt
# removing ./corpus/alignment/sentence_level_text/0638_648960_650930.txt
# ./corpus/alignment/sentence_level_text/0638_702580_703380.txt
# removing ./corpus/alignment/sentence_level_text/0638_702580_703380.txt
# ./corpus/alignment/sentence_level_text/4074_453490_457890.txt
# removing ./corpus/alignment/sentence_level_text/4074_453490_457890.txt
# ./corpus/alignment/sentence_level_text/4065_629920_631150.txt
# removing ./corpus/alignment/sentence_level_text/4065_629920_631150.txt
# ./corpus/alignment/sentence_level_text/4074_229600_230250.txt
# removing ./corpus/alignment/sentence_level_text/4074_229600_230250.txt
# ./corpus/alignment/sentence_level_text/4074_602940_607450.txt
# removing ./corpus/alignment/sentence_level_text/4074_602940_607450.txt
# ./corpus/alignment/sentence_level_text/4065_1110500_1112690.txt
# ./corpus/alignment/sentence_level_text/0638_224030_225880.txt
# removing ./corpus/alignment/sentence_level_text/0638_224030_225880.txt
# ./corpus/alignment/sentence_level_text/0638_340810_341860.txt
# removing ./corpus/alignment/sentence_level_text/0638_340810_341860.txt
# ./corpus/alignment/sentence_level_text/4074_408270_408770.txt
# removing ./corpus/alignment/sentence_level_text/4074_408270_408770.txt
# ./corpus/alignment/sentence_level_text/0638_316750_318560.txt
# removing ./corpus/alignment/sentence_level_text/0638_316750_318560.txt
# ./corpus/alignment/sentence_level_text/4065_863100_863970.txt
# removing ./corpus/alignment/sentence_level_text/4065_863100_863970.txt
# ./corpus/alignment/sentence_level_text/4074_262750_263560.txt
# removing ./corpus/alignment/sentence_level_text/4074_262750_263560.txt
# ./corpus/alignment/sentence_level_text/4065_596670_597320.txt
# ./corpus/alignment/sentence_level_text/4074_215390_216690.txt
# removing ./corpus/alignment/sentence_level_text/4074_215390_216690.txt
# ./corpus/alignment/sentence_level_text/4074_265050_266030.txt
# removing ./corpus/alignment/sentence_level_text/4074_265050_266030.txt
# ./corpus/alignment/sentence_level_text/4065_918240_921050.txt
# removing ./corpus/alignment/sentence_level_text/4065_918240_921050.txt
# ./corpus/alignment/sentence_level_text/4065_1112580_1118210.txt
# ./corpus/alignment/sentence_level_text/4065_884100_884870.txt
# removing ./corpus/alignment/sentence_level_text/4065_884100_884870.txt
# ./corpus/alignment/sentence_level_text/0638_785320_786930.txt
# removing ./corpus/alignment/sentence_level_text/0638_785320_786930.txt
# ./corpus/alignment/sentence_level_text/0638_550980_551530.txt
# removing ./corpus/alignment/sentence_level_text/0638_550980_551530.txt
# ./corpus/alignment/sentence_level_text/0638_728070_728220.txt
# removing ./corpus/alignment/sentence_level_text/0638_728070_728220.txt
# ./corpus/alignment/sentence_level_text/0638_327680_329620.txt
# removing ./corpus/alignment/sentence_level_text/0638_327680_329620.txt
# ./corpus/alignment/sentence_level_text/0638_573290_574910.txt
# removing ./corpus/alignment/sentence_level_text/0638_573290_574910.txt
# ./corpus/alignment/sentence_level_text/4074_262980_263610.txt
# removing ./corpus/alignment/sentence_level_text/4074_262980_263610.txt
# ./corpus/alignment/sentence_level_text/0638_588900_590730.txt
# removing ./corpus/alignment/sentence_level_text/0638_588900_590730.txt
# ./corpus/alignment/sentence_level_text/4065_1069850_1072340.txt
# ./corpus/alignment/sentence_level_text/4074_188941_193930.txt
# removing ./corpus/alignment/sentence_level_text/4074_188941_193930.txt
# ./corpus/alignment/sentence_level_text/0638_744140_744440.txt
# removing ./corpus/alignment/sentence_level_text/0638_744140_744440.txt
# ./corpus/alignment/sentence_level_text/0638_321690_324360.txt
# removing ./corpus/alignment/sentence_level_text/0638_321690_324360.txt
# ./corpus/alignment/sentence_level_text/4065_838510_839220.txt
# removing ./corpus/alignment/sentence_level_text/4065_838510_839220.txt
# ./corpus/alignment/sentence_level_text/4065_641970_642700.txt
# removing ./corpus/alignment/sentence_level_text/4065_641970_642700.txt
# ./corpus/alignment/sentence_level_text/4074_576290_579540.txt
# removing ./corpus/alignment/sentence_level_text/4074_576290_579540.txt
# ./corpus/alignment/sentence_level_text/4065_775440_775960.txt
# ./corpus/alignment/sentence_level_text/0638_417570_418520.txt
# removing ./corpus/alignment/sentence_level_text/0638_417570_418520.txt
# ./corpus/alignment/sentence_level_text/4065_863930_866580.txt
# removing ./corpus/alignment/sentence_level_text/4065_863930_866580.txt
# ./corpus/alignment/sentence_level_text/0638_424250_429220.txt
# removing ./corpus/alignment/sentence_level_text/0638_424250_429220.txt
# ./corpus/alignment/sentence_level_text/0638_799170_799480.txt
# removing ./corpus/alignment/sentence_level_text/0638_799170_799480.txt
# ./corpus/alignment/sentence_level_text/4074_159660_159910.txt
# removing ./corpus/alignment/sentence_level_text/4074_159660_159910.txt
# ./corpus/alignment/sentence_level_text/0638_480050_480420.txt
# removing ./corpus/alignment/sentence_level_text/0638_480050_480420.txt
# ./corpus/alignment/sentence_level_text/4065_813500_815740.txt
# removing ./corpus/alignment/sentence_level_text/4065_813500_815740.txt
# ./corpus/alignment/sentence_level_text/4074_386910_390060.txt
# removing ./corpus/alignment/sentence_level_text/4074_386910_390060.txt
# ./corpus/alignment/sentence_level_text/0638_402330_405700.txt
# removing ./corpus/alignment/sentence_level_text/0638_402330_405700.txt
# ./corpus/alignment/sentence_level_text/4074_201100_201870.txt
# removing ./corpus/alignment/sentence_level_text/4074_201100_201870.txt
# ./corpus/alignment/sentence_level_text/4065_713880_717340.txt
# ./corpus/alignment/sentence_level_text/4074_418740_422080.txt
# removing ./corpus/alignment/sentence_level_text/4074_418740_422080.txt
# ./corpus/alignment/sentence_level_text/4074_471780_473680.txt
# removing ./corpus/alignment/sentence_level_text/4074_471780_473680.txt
# ./corpus/alignment/sentence_level_text/0638_392420_392890.txt
# removing ./corpus/alignment/sentence_level_text/0638_392420_392890.txt
# ./corpus/alignment/sentence_level_text/4065_856320_860550.txt
# removing ./corpus/alignment/sentence_level_text/4065_856320_860550.txt
# ./corpus/alignment/sentence_level_text/0638_301860_303010.txt
# removing ./corpus/alignment/sentence_level_text/0638_301860_303010.txt
# ./corpus/alignment/sentence_level_text/0638_496500_497370.txt
# removing ./corpus/alignment/sentence_level_text/0638_496500_497370.txt
# ./corpus/alignment/sentence_level_text/4065_579360_579550.txt
# ./corpus/alignment/sentence_level_text/0638_713170_716060.txt
# removing ./corpus/alignment/sentence_level_text/0638_713170_716060.txt
# ./corpus/alignment/sentence_level_text/0638_544910_545150.txt
# removing ./corpus/alignment/sentence_level_text/0638_544910_545150.txt
# ./corpus/alignment/sentence_level_text/0638_478350_478710.txt
# removing ./corpus/alignment/sentence_level_text/0638_478350_478710.txt
# ./corpus/alignment/sentence_level_text/0638_583660_585200.txt
# removing ./corpus/alignment/sentence_level_text/0638_583660_585200.txt
# ./corpus/alignment/sentence_level_text/4074_494450_497960.txt
# removing ./corpus/alignment/sentence_level_text/4074_494450_497960.txt
# ./corpus/alignment/sentence_level_text/4065_717050_719030.txt
# removing ./corpus/alignment/sentence_level_text/4065_717050_719030.txt
# ./corpus/alignment/sentence_level_text/0638_255940_256340.txt
# ./corpus/alignment/sentence_level_text/0638_221170_221700.txt
# removing ./corpus/alignment/sentence_level_text/0638_221170_221700.txt
# ./corpus/alignment/sentence_level_text/4065_597280_599180.txt
# removing ./corpus/alignment/sentence_level_text/4065_597280_599180.txt
# ./corpus/alignment/sentence_level_text/4074_720471_722660.txt
# removing ./corpus/alignment/sentence_level_text/4074_720471_722660.txt
# ./corpus/alignment/sentence_level_text/0638_356100_357940.txt
# removing ./corpus/alignment/sentence_level_text/0638_356100_357940.txt
# ./corpus/alignment/sentence_level_text/0638_201140_201610.txt
# removing ./corpus/alignment/sentence_level_text/0638_201140_201610.txt
# ./corpus/alignment/sentence_level_text/4065_816670_817610.txt
# removing ./corpus/alignment/sentence_level_text/4065_816670_817610.txt
# ./corpus/alignment/sentence_level_text/0638_475310_475610.txt
# removing ./corpus/alignment/sentence_level_text/0638_475310_475610.txt
# ./corpus/alignment/sentence_level_text/0638_687660_688280.txt
# removing ./corpus/alignment/sentence_level_text/0638_687660_688280.txt
# ./corpus/alignment/sentence_level_text/0638_232940_234840.txt
# removing ./corpus/alignment/sentence_level_text/0638_232940_234840.txt
# ./corpus/alignment/sentence_level_text/4065_584080_585160.txt
# removing ./corpus/alignment/sentence_level_text/4065_584080_585160.txt
# ./corpus/alignment/sentence_level_text/0638_296940_297380.txt
# removing ./corpus/alignment/sentence_level_text/0638_296940_297380.txt
# ./corpus/alignment/sentence_level_text/4065_1073090_1076260.txt
# removing ./corpus/alignment/sentence_level_text/4065_1073090_1076260.txt
# ./corpus/alignment/sentence_level_text/0638_657240_657650.txt
# removing ./corpus/alignment/sentence_level_text/0638_657240_657650.txt
# ./corpus/alignment/sentence_level_text/0638_434880_435210.txt
# removing ./corpus/alignment/sentence_level_text/0638_434880_435210.txt
# ./corpus/alignment/sentence_level_text/4074_598840_599340.txt
# removing ./corpus/alignment/sentence_level_text/4074_598840_599340.txt
# ./corpus/alignment/sentence_level_text/4065_827810_828480.txt
# removing ./corpus/alignment/sentence_level_text/4065_827810_828480.txt
# ./corpus/alignment/sentence_level_text/4065_766580_770210.txt
# ./corpus/alignment/sentence_level_text/0638_644710_645100.txt
# ./corpus/alignment/sentence_level_text/4065_750710_753320.txt
# removing ./corpus/alignment/sentence_level_text/4065_750710_753320.txt
# ./corpus/alignment/sentence_level_text/0638_370010_373170.txt
# removing ./corpus/alignment/sentence_level_text/0638_370010_373170.txt
# ./corpus/alignment/sentence_level_text/0638_787850_790110.txt
# removing ./corpus/alignment/sentence_level_text/0638_787850_790110.txt
# ./corpus/alignment/sentence_level_text/0638_544130_544560.txt
# removing ./corpus/alignment/sentence_level_text/0638_544130_544560.txt
# ./corpus/alignment/sentence_level_text/4065_635440_635760.txt
# removing ./corpus/alignment/sentence_level_text/4065_635440_635760.txt
# ./corpus/alignment/sentence_level_text/4065_997400_1002550.txt
# removing ./corpus/alignment/sentence_level_text/4065_997400_1002550.txt
# ./corpus/alignment/sentence_level_text/0638_703400_704700.txt
# removing ./corpus/alignment/sentence_level_text/0638_703400_704700.txt
# ./corpus/alignment/sentence_level_text/4074_145150_147510.txt
# removing ./corpus/alignment/sentence_level_text/4074_145150_147510.txt
# ./corpus/alignment/sentence_level_text/4074_534720_540150.txt
# removing ./corpus/alignment/sentence_level_text/4074_534720_540150.txt
# ./corpus/alignment/sentence_level_text/0638_335740_335990.txt
# removing ./corpus/alignment/sentence_level_text/0638_335740_335990.txt
# ./corpus/alignment/sentence_level_text/0638_771550_774170.txt
# removing ./corpus/alignment/sentence_level_text/0638_771550_774170.txt
# ./corpus/alignment/sentence_level_text/4074_426970_433790.txt
# removing ./corpus/alignment/sentence_level_text/4074_426970_433790.txt
# ./corpus/alignment/sentence_level_text/4074_390920_391300.txt
# removing ./corpus/alignment/sentence_level_text/4074_390920_391300.txt
# ./corpus/alignment/sentence_level_text/0638_304880_305500.txt
# removing ./corpus/alignment/sentence_level_text/0638_304880_305500.txt
# ./corpus/alignment/sentence_level_text/4074_723101_724000.txt
# removing ./corpus/alignment/sentence_level_text/4074_723101_724000.txt
# ./corpus/alignment/sentence_level_text/4065_917150_918150.txt
# removing ./corpus/alignment/sentence_level_text/4065_917150_918150.txt
# ./corpus/alignment/sentence_level_text/4074_625210_627550.txt
# removing ./corpus/alignment/sentence_level_text/4074_625210_627550.txt
# ./corpus/alignment/sentence_level_text/0638_557480_561280.txt
# removing ./corpus/alignment/sentence_level_text/0638_557480_561280.txt
# ./corpus/alignment/sentence_level_text/4074_405070_406910.txt
# removing ./corpus/alignment/sentence_level_text/4074_405070_406910.txt
# ./corpus/alignment/sentence_level_text/0638_781190_781720.txt
# removing ./corpus/alignment/sentence_level_text/0638_781190_781720.txt
# ./corpus/alignment/sentence_level_text/4065_692590_693150.txt
# removing ./corpus/alignment/sentence_level_text/4065_692590_693150.txt
# ./corpus/alignment/sentence_level_text/0638_393140_395180.txt
# removing ./corpus/alignment/sentence_level_text/0638_393140_395180.txt
# ./corpus/alignment/sentence_level_text/4074_562230_569480.txt
# ./corpus/alignment/sentence_level_text/0638_755960_757040.txt
# removing ./corpus/alignment/sentence_level_text/0638_755960_757040.txt
# ./corpus/alignment/sentence_level_text/4074_710880_712420.txt
# removing ./corpus/alignment/sentence_level_text/4074_710880_712420.txt
# ./corpus/alignment/sentence_level_text/0638_412390_412810.txt
# removing ./corpus/alignment/sentence_level_text/0638_412390_412810.txt
# ./corpus/alignment/sentence_level_text/0638_430310_432040.txt
# removing ./corpus/alignment/sentence_level_text/0638_430310_432040.txt
# ./corpus/alignment/sentence_level_text/4065_669350_669690.txt
# removing ./corpus/alignment/sentence_level_text/4065_669350_669690.txt
# ./corpus/alignment/sentence_level_text/4074_711440_715290.txt
# removing ./corpus/alignment/sentence_level_text/4074_711440_715290.txt
# ./corpus/alignment/sentence_level_text/4065_742100_743810.txt
# removing ./corpus/alignment/sentence_level_text/4065_742100_743810.txt
# ./corpus/alignment/sentence_level_text/4065_835800_836630.txt
# removing ./corpus/alignment/sentence_level_text/4065_835800_836630.txt
# ./corpus/alignment/sentence_level_text/4065_650020_653520.txt
# removing ./corpus/alignment/sentence_level_text/4065_650020_653520.txt
# ./corpus/alignment/sentence_level_text/0638_406910_407180.txt
# removing ./corpus/alignment/sentence_level_text/0638_406910_407180.txt
# ./corpus/alignment/sentence_level_text/0638_516050_517080.txt
# removing ./corpus/alignment/sentence_level_text/0638_516050_517080.txt
# ./corpus/alignment/sentence_level_text/4065_1036439_1036990.txt
# removing ./corpus/alignment/sentence_level_text/4065_1036439_1036990.txt
# ./corpus/alignment/sentence_level_text/0638_556200_557140.txt
# removing ./corpus/alignment/sentence_level_text/0638_556200_557140.txt
# ./corpus/alignment/sentence_level_text/0638_517890_518700.txt
# removing ./corpus/alignment/sentence_level_text/0638_517890_518700.txt
# ./corpus/alignment/sentence_level_text/4074_359220_361240.txt
# removing ./corpus/alignment/sentence_level_text/4074_359220_361240.txt
# ./corpus/alignment/sentence_level_text/0638_238620_238960.txt
# ./corpus/alignment/sentence_level_text/0638_236510_238000.txt
# removing ./corpus/alignment/sentence_level_text/0638_236510_238000.txt
# ./corpus/alignment/sentence_level_text/4074_336390_339840.txt
# removing ./corpus/alignment/sentence_level_text/4074_336390_339840.txt
# ./corpus/alignment/sentence_level_text/4074_590310_591710.txt
# removing ./corpus/alignment/sentence_level_text/4074_590310_591710.txt
# ./corpus/alignment/sentence_level_text/4074_300090_300870.txt
# removing ./corpus/alignment/sentence_level_text/4074_300090_300870.txt
# ./corpus/alignment/sentence_level_text/0638_210850_212500.txt
# removing ./corpus/alignment/sentence_level_text/0638_210850_212500.txt
# ./corpus/alignment/sentence_level_text/4065_592710_596470.txt
# removing ./corpus/alignment/sentence_level_text/4065_592710_596470.txt
# ./corpus/alignment/sentence_level_text/4074_745240_745610.txt
# removing ./corpus/alignment/sentence_level_text/4074_745240_745610.txt
# ./corpus/alignment/sentence_level_text/4065_600430_601700.txt
# removing ./corpus/alignment/sentence_level_text/4065_600430_601700.txt
# ./corpus/alignment/sentence_level_text/0638_662290_663480.txt
# removing ./corpus/alignment/sentence_level_text/0638_662290_663480.txt
# ./corpus/alignment/sentence_level_text/0638_791520_792820.txt
# removing ./corpus/alignment/sentence_level_text/0638_791520_792820.txt
# ./corpus/alignment/sentence_level_text/0638_539880_540060.txt
# removing ./corpus/alignment/sentence_level_text/0638_539880_540060.txt
# ./corpus/alignment/sentence_level_text/0638_499830_500510.txt
# removing ./corpus/alignment/sentence_level_text/0638_499830_500510.txt
# ./corpus/alignment/sentence_level_text/0638_432240_433020.txt
# removing ./corpus/alignment/sentence_level_text/0638_432240_433020.txt
# ./corpus/alignment/sentence_level_text/0638_718090_718410.txt
# removing ./corpus/alignment/sentence_level_text/0638_718090_718410.txt
# ./corpus/alignment/sentence_level_text/4065_753420_754150.txt
# removing ./corpus/alignment/sentence_level_text/4065_753420_754150.txt
# ./corpus/alignment/sentence_level_text/0638_365240_369460.txt
# removing ./corpus/alignment/sentence_level_text/0638_365240_369460.txt
# ./corpus/alignment/sentence_level_text/0638_243490_243760.txt
# removing ./corpus/alignment/sentence_level_text/0638_243490_243760.txt
# ./corpus/alignment/sentence_level_text/4074_547550_548120.txt
# removing ./corpus/alignment/sentence_level_text/4074_547550_548120.txt
# ./corpus/alignment/sentence_level_text/4065_795760_797700.txt
# removing ./corpus/alignment/sentence_level_text/4065_795760_797700.txt
# ./corpus/alignment/sentence_level_text/4065_1013520_1018570.txt
# removing ./corpus/alignment/sentence_level_text/4065_1013520_1018570.txt
# ./corpus/alignment/sentence_level_text/0638_639490_640440.txt
# removing ./corpus/alignment/sentence_level_text/0638_639490_640440.txt
# ./corpus/alignment/sentence_level_text/0638_324530_325190.txt
# removing ./corpus/alignment/sentence_level_text/0638_324530_325190.txt
# ./corpus/alignment/sentence_level_text/0638_234970_235470.txt
# ./corpus/alignment/sentence_level_text/0638_618920_619450.txt
# removing ./corpus/alignment/sentence_level_text/0638_618920_619450.txt
# ./corpus/alignment/sentence_level_text/4065_620530_621300.txt
# removing ./corpus/alignment/sentence_level_text/4065_620530_621300.txt
# ./corpus/alignment/sentence_level_text/4065_633840_634940.txt
# removing ./corpus/alignment/sentence_level_text/4065_633840_634940.txt
# ./corpus/alignment/sentence_level_text/4065_1087530_1088760.txt
# removing ./corpus/alignment/sentence_level_text/4065_1087530_1088760.txt
# ./corpus/alignment/sentence_level_text/0638_551580_552050.txt
# removing ./corpus/alignment/sentence_level_text/0638_551580_552050.txt
# ./corpus/alignment/sentence_level_text/0638_737070_737380.txt
# removing ./corpus/alignment/sentence_level_text/0638_737070_737380.txt
# ./corpus/alignment/sentence_level_text/0638_712240_712920.txt
# removing ./corpus/alignment/sentence_level_text/0638_712240_712920.txt
# ./corpus/alignment/sentence_level_text/4065_1053231_1055460.txt
# removing ./corpus/alignment/sentence_level_text/4065_1053231_1055460.txt
# ./corpus/alignment/sentence_level_text/0638_405530_406230.txt
# removing ./corpus/alignment/sentence_level_text/0638_405530_406230.txt
# ./corpus/alignment/sentence_level_text/4074_681240_687810.txt
# removing ./corpus/alignment/sentence_level_text/4074_681240_687810.txt
# ./corpus/alignment/sentence_level_text/0638_736990_738340.txt
# removing ./corpus/alignment/sentence_level_text/0638_736990_738340.txt
# ./corpus/alignment/sentence_level_text/4065_645890_649060.txt
# removing ./corpus/alignment/sentence_level_text/4065_645890_649060.txt
# ./corpus/alignment/sentence_level_text/4065_1076970_1078590.txt
# ./corpus/alignment/sentence_level_text/0638_330040_330570.txt
# removing ./corpus/alignment/sentence_level_text/0638_330040_330570.txt
# ./corpus/alignment/sentence_level_text/4074_218650_220950.txt
# removing ./corpus/alignment/sentence_level_text/4074_218650_220950.txt
# ./corpus/alignment/sentence_level_text/0638_680940_681170.txt
# removing ./corpus/alignment/sentence_level_text/0638_680940_681170.txt
# ./corpus/alignment/sentence_level_text/0638_641420_642420.txt
# removing ./corpus/alignment/sentence_level_text/0638_641420_642420.txt
# ./corpus/alignment/sentence_level_text/0638_750270_753230.txt
# removing ./corpus/alignment/sentence_level_text/0638_750270_753230.txt
# ./corpus/alignment/sentence_level_text/0638_432810_433450.txt
# removing ./corpus/alignment/sentence_level_text/0638_432810_433450.txt
# ./corpus/alignment/sentence_level_text/0638_352780_353550.txt
# removing ./corpus/alignment/sentence_level_text/0638_352780_353550.txt
# ./corpus/alignment/sentence_level_text/0638_242840_243360.txt
# removing ./corpus/alignment/sentence_level_text/0638_242840_243360.txt
# ./corpus/alignment/sentence_level_text/4074_445490_448830.txt
# removing ./corpus/alignment/sentence_level_text/4074_445490_448830.txt
# ./corpus/alignment/sentence_level_text/0638_281080_281360.txt
# removing ./corpus/alignment/sentence_level_text/0638_281080_281360.txt
# ./corpus/alignment/sentence_level_text/4074_746550_747720.txt
# removing ./corpus/alignment/sentence_level_text/4074_746550_747720.txt
# ./corpus/alignment/sentence_level_text/4074_202310_214010.txt
# removing ./corpus/alignment/sentence_level_text/4074_202310_214010.txt
# ./corpus/alignment/sentence_level_text/0638_735130_735860.txt
# removing ./corpus/alignment/sentence_level_text/0638_735130_735860.txt
# ./corpus/alignment/sentence_level_text/0638_757490_760190.txt
# removing ./corpus/alignment/sentence_level_text/0638_757490_760190.txt
# ./corpus/alignment/sentence_level_text/0638_585610_586480.txt
# removing ./corpus/alignment/sentence_level_text/0638_585610_586480.txt
# ./corpus/alignment/sentence_level_text/0638_331780_332190.txt
# removing ./corpus/alignment/sentence_level_text/0638_331780_332190.txt
# ./corpus/alignment/sentence_level_text/4074_716140_719930.txt
# removing ./corpus/alignment/sentence_level_text/4074_716140_719930.txt
# ./corpus/alignment/sentence_level_text/0638_297620_298660.txt
# removing ./corpus/alignment/sentence_level_text/0638_297620_298660.txt
# ./corpus/alignment/sentence_level_text/4065_917260_917800.txt
# removing ./corpus/alignment/sentence_level_text/4065_917260_917800.txt
# ./corpus/alignment/sentence_level_text/0638_655080_656990.txt
# removing ./corpus/alignment/sentence_level_text/0638_655080_656990.txt
# ./corpus/alignment/sentence_level_text/4065_729770_730330.txt
# removing ./corpus/alignment/sentence_level_text/4065_729770_730330.txt
# ./corpus/alignment/sentence_level_text/4074_499490_504170.txt
# removing ./corpus/alignment/sentence_level_text/4074_499490_504170.txt
# ./corpus/alignment/sentence_level_text/4065_1117950_1121160.txt
# removing ./corpus/alignment/sentence_level_text/4065_1117950_1121160.txt
# ./corpus/alignment/sentence_level_text/0638_781700_782560.txt
# removing ./corpus/alignment/sentence_level_text/0638_781700_782560.txt
# ./corpus/alignment/sentence_level_text/4065_847250_849270.txt
# removing ./corpus/alignment/sentence_level_text/4065_847250_849270.txt
# ./corpus/alignment/sentence_level_text/4065_922430_931710.txt
# removing ./corpus/alignment/sentence_level_text/4065_922430_931710.txt
# ./corpus/alignment/sentence_level_text/4074_707350_710610.txt
# removing ./corpus/alignment/sentence_level_text/4074_707350_710610.txt
# ./corpus/alignment/sentence_level_text/0638_429460_429780.txt
# removing ./corpus/alignment/sentence_level_text/0638_429460_429780.txt
# ./corpus/alignment/sentence_level_text/4065_789460_790420.txt
# removing ./corpus/alignment/sentence_level_text/4065_789460_790420.txt
# ./corpus/alignment/sentence_level_text/4065_754420_755300.txt
# removing ./corpus/alignment/sentence_level_text/4065_754420_755300.txt
# ./corpus/alignment/sentence_level_text/4074_194560_197690.txt
# removing ./corpus/alignment/sentence_level_text/4074_194560_197690.txt
# ./corpus/alignment/sentence_level_text/4065_1010190_1013550.txt
# removing ./corpus/alignment/sentence_level_text/4065_1010190_1013550.txt
# ./corpus/alignment/sentence_level_text/4074_163100_169250.txt
# ./corpus/alignment/sentence_level_text/4074_246990_247620.txt
# ./corpus/alignment/sentence_level_text/0638_411070_411510.txt
# removing ./corpus/alignment/sentence_level_text/0638_411070_411510.txt
# ./corpus/alignment/sentence_level_text/4065_695780_699630.txt
# removing ./corpus/alignment/sentence_level_text/4065_695780_699630.txt
# ./corpus/alignment/sentence_level_text/0638_222230_223770.txt
# removing ./corpus/alignment/sentence_level_text/0638_222230_223770.txt
# ./corpus/alignment/sentence_level_text/4074_524210_528090.txt
# removing ./corpus/alignment/sentence_level_text/4074_524210_528090.txt
# ./corpus/alignment/sentence_level_text/4065_744080_744310.txt
# removing ./corpus/alignment/sentence_level_text/4065_744080_744310.txt
# ./corpus/alignment/sentence_level_text/4065_661200_664680.txt
# removing ./corpus/alignment/sentence_level_text/4065_661200_664680.txt
# ./corpus/alignment/sentence_level_text/0638_698160_700100.txt
# removing ./corpus/alignment/sentence_level_text/0638_698160_700100.txt
# ./corpus/alignment/sentence_level_text/4074_319170_321030.txt
# removing ./corpus/alignment/sentence_level_text/4074_319170_321030.txt
# ./corpus/alignment/sentence_level_text/4065_807140_809040.txt
# removing ./corpus/alignment/sentence_level_text/4065_807140_809040.txt
# ./corpus/alignment/sentence_level_text/4065_971230_971420.txt
# ./corpus/alignment/sentence_level_text/4065_1018680_1029750.txt
# removing ./corpus/alignment/sentence_level_text/4065_1018680_1029750.txt
# ./corpus/alignment/sentence_level_text/0638_339940_340270.txt
# removing ./corpus/alignment/sentence_level_text/0638_339940_340270.txt
# ./corpus/alignment/sentence_level_text/0638_543920_544410.txt
# removing ./corpus/alignment/sentence_level_text/0638_543920_544410.txt
# ./corpus/alignment/sentence_level_text/0638_385780_386330.txt
# removing ./corpus/alignment/sentence_level_text/0638_385780_386330.txt
# ./corpus/alignment/sentence_level_text/4074_251130_252630.txt
# removing ./corpus/alignment/sentence_level_text/4074_251130_252630.txt
# ./corpus/alignment/sentence_level_text/4065_570860_575780.txt
# removing ./corpus/alignment/sentence_level_text/4065_570860_575780.txt
# ./corpus/alignment/sentence_level_text/4074_321890_332630.txt
# removing ./corpus/alignment/sentence_level_text/4074_321890_332630.txt
# ./corpus/alignment/sentence_level_text/0638_765210_766520.txt
# removing ./corpus/alignment/sentence_level_text/0638_765210_766520.txt
# ./corpus/alignment/sentence_level_text/4074_361830_362200.txt
# ./corpus/alignment/sentence_level_text/0638_611990_612340.txt
# ./corpus/alignment/sentence_level_text/0638_591140_591710.txt
# removing ./corpus/alignment/sentence_level_text/0638_591140_591710.txt
# ./corpus/alignment/sentence_level_text/4074_562230_562500.txt
# removing ./corpus/alignment/sentence_level_text/4074_562230_562500.txt
# ./corpus/alignment/sentence_level_text/0638_755430_755650.txt
# removing ./corpus/alignment/sentence_level_text/0638_755430_755650.txt
# ./corpus/alignment/sentence_level_text/4074_587911_589290.txt
# removing ./corpus/alignment/sentence_level_text/4074_587911_589290.txt
# ./corpus/alignment/sentence_level_text/4074_217080_218300.txt
# removing ./corpus/alignment/sentence_level_text/4074_217080_218300.txt
# ./corpus/alignment/sentence_level_text/0638_620300_621450.txt
# removing ./corpus/alignment/sentence_level_text/0638_620300_621450.txt
# ./corpus/alignment/sentence_level_text/0638_720360_721480.txt
# removing ./corpus/alignment/sentence_level_text/0638_720360_721480.txt
# ./corpus/alignment/sentence_level_text/4074_273320_275390.txt
# removing ./corpus/alignment/sentence_level_text/4074_273320_275390.txt
# ./corpus/alignment/sentence_level_text/4065_658130_661280.txt
# removing ./corpus/alignment/sentence_level_text/4065_658130_661280.txt
# ./corpus/alignment/sentence_level_text/0638_282840_283340.txt
# removing ./corpus/alignment/sentence_level_text/0638_282840_283340.txt
# ./corpus/alignment/sentence_level_text/4065_724930_725270.txt
# removing ./corpus/alignment/sentence_level_text/4065_724930_725270.txt
# ./corpus/alignment/sentence_level_text/0638_658300_659590.txt
# removing ./corpus/alignment/sentence_level_text/0638_658300_659590.txt
# ./corpus/alignment/sentence_level_text/4065_579361_583180.txt
# removing ./corpus/alignment/sentence_level_text/4065_579361_583180.txt
# ./corpus/alignment/sentence_level_text/4074_266930_272760.txt
# removing ./corpus/alignment/sentence_level_text/4074_266930_272760.txt
# ./corpus/alignment/sentence_level_text/0638_439580_439710.txt
# removing ./corpus/alignment/sentence_level_text/0638_439580_439710.txt
# ./corpus/alignment/sentence_level_text/4065_1101950_1106530.txt
# removing ./corpus/alignment/sentence_level_text/4065_1101950_1106530.txt
# ./corpus/alignment/sentence_level_text/0638_514419_514840.txt
# removing ./corpus/alignment/sentence_level_text/0638_514419_514840.txt
# ./corpus/alignment/sentence_level_text/4065_902220_910600.txt
# ./corpus/alignment/sentence_level_text/4065_731020_741850.txt
# removing ./corpus/alignment/sentence_level_text/4065_731020_741850.txt
# ./corpus/alignment/sentence_level_text/4074_261200_262160.txt
# removing ./corpus/alignment/sentence_level_text/4074_261200_262160.txt
# ./corpus/alignment/sentence_level_text/0638_498170_498690.txt
# removing ./corpus/alignment/sentence_level_text/0638_498170_498690.txt
# ./corpus/alignment/sentence_level_text/4065_670420_675670.txt
# removing ./corpus/alignment/sentence_level_text/4065_670420_675670.txt
# ./corpus/alignment/sentence_level_text/0638_422250_422650.txt
# removing ./corpus/alignment/sentence_level_text/0638_422250_422650.txt
# ./corpus/alignment/sentence_level_text/0638_596370_597960.txt
# removing ./corpus/alignment/sentence_level_text/0638_596370_597960.txt
# ./corpus/alignment/sentence_level_text/0638_345240_345770.txt
# removing ./corpus/alignment/sentence_level_text/0638_345240_345770.txt
# ./corpus/alignment/sentence_level_text/0638_385070_385400.txt
# removing ./corpus/alignment/sentence_level_text/0638_385070_385400.txt
# ./corpus/alignment/sentence_level_text/4065_880490_883180.txt
# removing ./corpus/alignment/sentence_level_text/4065_880490_883180.txt
# ./corpus/alignment/sentence_level_text/4065_885850_886250.txt
# removing ./corpus/alignment/sentence_level_text/4065_885850_886250.txt
# ./corpus/alignment/sentence_level_text/0638_358470_361170.txt
# removing ./corpus/alignment/sentence_level_text/0638_358470_361170.txt
# ./corpus/alignment/sentence_level_text/4074_460870_465860.txt
# removing ./corpus/alignment/sentence_level_text/4074_460870_465860.txt
# ./corpus/alignment/sentence_level_text/0638_551120_551550.txt
# ./corpus/alignment/sentence_level_text/4074_688310_688930.txt
# removing ./corpus/alignment/sentence_level_text/4074_688310_688930.txt
# ./corpus/alignment/sentence_level_text/4074_379280_379680.txt
# removing ./corpus/alignment/sentence_level_text/4074_379280_379680.txt
# ./corpus/alignment/sentence_level_text/0638_623940_624440.txt
# removing ./corpus/alignment/sentence_level_text/0638_623940_624440.txt
# ./corpus/alignment/sentence_level_text/0638_654290_654590.txt
# removing ./corpus/alignment/sentence_level_text/0638_654290_654590.txt
# ./corpus/alignment/sentence_level_text/0638_526850_527930.txt
# removing ./corpus/alignment/sentence_level_text/0638_526850_527930.txt
# ./corpus/alignment/sentence_level_text/4065_914190_914480.txt
# removing ./corpus/alignment/sentence_level_text/4065_914190_914480.txt
# ./corpus/alignment/sentence_level_text/4065_659180_659450.txt
# removing ./corpus/alignment/sentence_level_text/4065_659180_659450.txt
# ./corpus/alignment/sentence_level_text/0638_492880_493550.txt
# removing ./corpus/alignment/sentence_level_text/0638_492880_493550.txt
# ./corpus/alignment/sentence_level_text/4065_970350_971940.txt
# removing ./corpus/alignment/sentence_level_text/4065_970350_971940.txt
# ./corpus/alignment/sentence_level_text/0638_481160_482170.txt
# removing ./corpus/alignment/sentence_level_text/0638_481160_482170.txt
# ./corpus/alignment/sentence_level_text/0638_219150_219560.txt
# ./corpus/alignment/sentence_level_text/4074_159661_160740.txt
# removing ./corpus/alignment/sentence_level_text/4074_159661_160740.txt
# ./corpus/alignment/sentence_level_text/0638_309870_314080.txt
# removing ./corpus/alignment/sentence_level_text/0638_309870_314080.txt
# ./corpus/alignment/sentence_level_text/4065_1088690_1090670.txt
# removing ./corpus/alignment/sentence_level_text/4065_1088690_1090670.txt
# ./corpus/alignment/sentence_level_text/4074_702640_706090.txt
# removing ./corpus/alignment/sentence_level_text/4074_702640_706090.txt
# ./corpus/alignment/sentence_level_text/4074_217210_218090.txt
# removing ./corpus/alignment/sentence_level_text/4074_217210_218090.txt
# ./corpus/alignment/sentence_level_text/4074_585880_587220.txt
# removing ./corpus/alignment/sentence_level_text/4074_585880_587220.txt
# ./corpus/alignment/sentence_level_text/4065_911290_913920.txt
# ./corpus/alignment/sentence_level_text/4074_671840_672090.txt
# ./corpus/alignment/sentence_level_text/4065_682700_684330.txt
# removing ./corpus/alignment/sentence_level_text/4065_682700_684330.txt
# ./corpus/alignment/sentence_level_text/4065_942950_943450.txt
# removing ./corpus/alignment/sentence_level_text/4065_942950_943450.txt
# ./corpus/alignment/sentence_level_text/4065_685620_689540.txt
# removing ./corpus/alignment/sentence_level_text/4065_685620_689540.txt
# ./corpus/alignment/sentence_level_text/0638_244030_245450.txt
# removing ./corpus/alignment/sentence_level_text/0638_244030_245450.txt
# ./corpus/alignment/sentence_level_text/4074_252280_255060.txt
# removing ./corpus/alignment/sentence_level_text/4074_252280_255060.txt
# ./corpus/alignment/sentence_level_text/0638_382410_384410.txt
# removing ./corpus/alignment/sentence_level_text/0638_382410_384410.txt
# ./corpus/alignment/sentence_level_text/0638_581190_581480.txt
# removing ./corpus/alignment/sentence_level_text/0638_581190_581480.txt
# ./corpus/alignment/sentence_level_text/4074_747660_750270.txt
# removing ./corpus/alignment/sentence_level_text/4074_747660_750270.txt
# ./corpus/alignment/sentence_level_text/0638_397800_398160.txt
# removing ./corpus/alignment/sentence_level_text/0638_397800_398160.txt
# ./corpus/alignment/sentence_level_text/0638_609350_611630.txt
# removing ./corpus/alignment/sentence_level_text/0638_609350_611630.txt
# ./corpus/alignment/sentence_level_text/0638_385850_386220.txt
# removing ./corpus/alignment/sentence_level_text/0638_385850_386220.txt
# ./corpus/alignment/sentence_level_text/0638_219880_220680.txt
# removing ./corpus/alignment/sentence_level_text/0638_219880_220680.txt
# ./corpus/alignment/sentence_level_text/0638_597380_597460.txt
# removing ./corpus/alignment/sentence_level_text/0638_597380_597460.txt
# ./corpus/alignment/sentence_level_text/4074_670690_672070.txt
# removing ./corpus/alignment/sentence_level_text/4074_670690_672070.txt
# ./corpus/alignment/sentence_level_text/0638_455090_456240.txt
# removing ./corpus/alignment/sentence_level_text/0638_455090_456240.txt
# ./corpus/alignment/sentence_level_text/0638_271740_272510.txt
# removing ./corpus/alignment/sentence_level_text/0638_271740_272510.txt
# ./corpus/alignment/sentence_level_text/0638_769330_770580.txt
# removing ./corpus/alignment/sentence_level_text/0638_769330_770580.txt
# ./corpus/alignment/sentence_level_text/4065_628390_629250.txt
# removing ./corpus/alignment/sentence_level_text/4065_628390_629250.txt
# ./corpus/alignment/sentence_level_text/4074_480570_484800.txt
# removing ./corpus/alignment/sentence_level_text/4074_480570_484800.txt
# ./corpus/alignment/sentence_level_text/4074_651440_658480.txt
# removing ./corpus/alignment/sentence_level_text/4074_651440_658480.txt
# ./corpus/alignment/sentence_level_text/0638_226170_226550.txt
# removing ./corpus/alignment/sentence_level_text/0638_226170_226550.txt
# ./corpus/alignment/sentence_level_text/4065_765910_766660.txt
# removing ./corpus/alignment/sentence_level_text/4065_765910_766660.txt
# ./corpus/alignment/sentence_level_text/0638_717650_718620.txt
# removing ./corpus/alignment/sentence_level_text/0638_717650_718620.txt
# ./corpus/alignment/sentence_level_text/0638_280010_280360.txt
# ./corpus/alignment/sentence_level_text/4065_791880_794340.txt
# removing ./corpus/alignment/sentence_level_text/4065_791880_794340.txt
# ./corpus/alignment/sentence_level_text/4065_818110_821070.txt
# removing ./corpus/alignment/sentence_level_text/4065_818110_821070.txt
# ./corpus/alignment/sentence_level_text/4074_442940_443670.txt
# removing ./corpus/alignment/sentence_level_text/4074_442940_443670.txt
# ./corpus/alignment/sentence_level_text/0638_293110_293680.txt
# removing ./corpus/alignment/sentence_level_text/0638_293110_293680.txt
# ./corpus/alignment/sentence_level_text/0638_334710_335250.txt
# removing ./corpus/alignment/sentence_level_text/0638_334710_335250.txt
# ./corpus/alignment/sentence_level_text/4065_559360_559860.txt
# removing ./corpus/alignment/sentence_level_text/4065_559360_559860.txt
# ./corpus/alignment/sentence_level_text/4065_794750_795440.txt
# ./corpus/alignment/sentence_level_text/4065_1013380_1013610.txt
# removing ./corpus/alignment/sentence_level_text/4065_1013380_1013610.txt
# ./corpus/alignment/sentence_level_text/4074_477570_479430.txt
# ./corpus/alignment/sentence_level_text/4074_409240_412720.txt
# removing ./corpus/alignment/sentence_level_text/4074_409240_412720.txt
# ./corpus/alignment/sentence_level_text/4065_1018150_1018400.txt
# ./corpus/alignment/sentence_level_text/0638_277380_277690.txt
# removing ./corpus/alignment/sentence_level_text/0638_277380_277690.txt
# ./corpus/alignment/sentence_level_text/4074_276080_284320.txt
# removing ./corpus/alignment/sentence_level_text/4074_276080_284320.txt
# ./corpus/alignment/sentence_level_text/4074_607430_611960.txt
# removing ./corpus/alignment/sentence_level_text/4074_607430_611960.txt
# ./corpus/alignment/sentence_level_text/0638_653670_653980.txt
# removing ./corpus/alignment/sentence_level_text/0638_653670_653980.txt
# ./corpus/alignment/sentence_level_text/0638_599530_602330.txt
# removing ./corpus/alignment/sentence_level_text/0638_599530_602330.txt
# ./corpus/alignment/sentence_level_text/4074_214260_215390.txt
# removing ./corpus/alignment/sentence_level_text/4074_214260_215390.txt
# ./corpus/alignment/sentence_level_text/0638_613060_613610.txt
# removing ./corpus/alignment/sentence_level_text/0638_613060_613610.txt
# ./corpus/alignment/sentence_level_text/0638_728950_730130.txt
# removing ./corpus/alignment/sentence_level_text/0638_728950_730130.txt
# ./corpus/alignment/sentence_level_text/4074_624010_625090.txt
# removing ./corpus/alignment/sentence_level_text/4074_624010_625090.txt
# ./corpus/alignment/sentence_level_text/0638_622920_623750.txt
# removing ./corpus/alignment/sentence_level_text/0638_622920_623750.txt
# ./corpus/alignment/sentence_level_text/4065_707460_708040.txt
# removing ./corpus/alignment/sentence_level_text/4065_707460_708040.txt
# ./corpus/alignment/sentence_level_text/0638_761010_761740.txt
# removing ./corpus/alignment/sentence_level_text/0638_761010_761740.txt
# ./corpus/alignment/sentence_level_text/4074_392300_392800.txt
# removing ./corpus/alignment/sentence_level_text/4074_392300_392800.txt
# ./corpus/alignment/sentence_level_text/4074_222540_225420.txt
# removing ./corpus/alignment/sentence_level_text/4074_222540_225420.txt
# ./corpus/alignment/sentence_level_text/0638_534240_535510.txt
# removing ./corpus/alignment/sentence_level_text/0638_534240_535510.txt
# ./corpus/alignment/sentence_level_text/4074_155500_158710.txt
# ./corpus/alignment/sentence_level_text/0638_602850_603610.txt
# removing ./corpus/alignment/sentence_level_text/0638_602850_603610.txt
# ./corpus/alignment/sentence_level_text/0638_442650_445360.txt
# removing ./corpus/alignment/sentence_level_text/0638_442650_445360.txt
# ./corpus/alignment/sentence_level_text/0638_725910_727530.txt
# removing ./corpus/alignment/sentence_level_text/0638_725910_727530.txt
# ./corpus/alignment/sentence_level_text/4065_567790_570290.txt
# removing ./corpus/alignment/sentence_level_text/4065_567790_570290.txt
# ./corpus/alignment/sentence_level_text/0638_651290_652700.txt
# removing ./corpus/alignment/sentence_level_text/0638_651290_652700.txt
# ./corpus/alignment/sentence_level_text/0638_265530_266760.txt
# removing ./corpus/alignment/sentence_level_text/0638_265530_266760.txt
# ./corpus/alignment/sentence_level_text/4065_744180_748560.txt
# removing ./corpus/alignment/sentence_level_text/4065_744180_748560.txt
# ./corpus/alignment/sentence_level_text/4065_951960_952670.txt
# removing ./corpus/alignment/sentence_level_text/4065_951960_952670.txt
# ./corpus/alignment/sentence_level_text/4074_288890_289100.txt
# removing ./corpus/alignment/sentence_level_text/4074_288890_289100.txt
# ./corpus/alignment/sentence_level_text/4074_646660_650420.txt
# removing ./corpus/alignment/sentence_level_text/4074_646660_650420.txt
# ./corpus/alignment/sentence_level_text/4074_516729_519860.txt
# removing ./corpus/alignment/sentence_level_text/4074_516729_519860.txt
# ./corpus/alignment/sentence_level_text/4065_1036440_1043990.txt
# removing ./corpus/alignment/sentence_level_text/4065_1036440_1043990.txt
# ./corpus/alignment/sentence_level_text/4074_728260_730680.txt
# removing ./corpus/alignment/sentence_level_text/4074_728260_730680.txt
# ./corpus/alignment/sentence_level_text/0638_451880_452140.txt
# removing ./corpus/alignment/sentence_level_text/0638_451880_452140.txt
# ./corpus/alignment/sentence_level_text/4065_1136800_1142860.txt
# removing ./corpus/alignment/sentence_level_text/4065_1136800_1142860.txt
# ./corpus/alignment/sentence_level_text/4065_783180_788640.txt
# ./corpus/alignment/sentence_level_text/4065_606860_607750.txt
# removing ./corpus/alignment/sentence_level_text/4065_606860_607750.txt
# ./corpus/alignment/sentence_level_text/0638_577510_579390.txt
# removing ./corpus/alignment/sentence_level_text/0638_577510_579390.txt
# ./corpus/alignment/sentence_level_text/4065_1084640_1087250.txt
# removing ./corpus/alignment/sentence_level_text/4065_1084640_1087250.txt
# ./corpus/alignment/sentence_level_text/4065_809940_810350.txt
# removing ./corpus/alignment/sentence_level_text/4065_809940_810350.txt
# ./corpus/alignment/sentence_level_text/4074_751130_751570.txt
# removing ./corpus/alignment/sentence_level_text/4074_751130_751570.txt
# ./corpus/alignment/sentence_level_text/4074_602250_602580.txt
# removing ./corpus/alignment/sentence_level_text/4074_602250_602580.txt
# ./corpus/alignment/sentence_level_text/4065_842330_842850.txt
# removing ./corpus/alignment/sentence_level_text/4065_842330_842850.txt
# ./corpus/alignment/sentence_level_text/4065_843760_846200.txt
# removing ./corpus/alignment/sentence_level_text/4065_843760_846200.txt
# ./corpus/alignment/sentence_level_text/4074_696370_697750.txt
# removing ./corpus/alignment/sentence_level_text/4074_696370_697750.txt
# ./corpus/alignment/sentence_level_text/0638_239420_242260.txt
# removing ./corpus/alignment/sentence_level_text/0638_239420_242260.txt
# ./corpus/alignment/sentence_level_text/4065_794820_795030.txt
# removing ./corpus/alignment/sentence_level_text/4065_794820_795030.txt
# ./corpus/alignment/sentence_level_text/0638_672930_673140.txt
# removing ./corpus/alignment/sentence_level_text/0638_672930_673140.txt
# ./corpus/alignment/sentence_level_text/4065_876630_876970.txt
# removing ./corpus/alignment/sentence_level_text/4065_876630_876970.txt
# ./corpus/alignment/sentence_level_text/4074_438990_439260.txt
# removing ./corpus/alignment/sentence_level_text/4074_438990_439260.txt
# ./corpus/alignment/sentence_level_text/4065_962680_970210.txt
# removing ./corpus/alignment/sentence_level_text/4065_962680_970210.txt
# ./corpus/alignment/sentence_level_text/0638_391920_392100.txt
# removing ./corpus/alignment/sentence_level_text/0638_391920_392100.txt
# ./corpus/alignment/sentence_level_text/0638_652560_652990.txt
# removing ./corpus/alignment/sentence_level_text/0638_652560_652990.txt
# ./corpus/alignment/sentence_level_text/4065_941010_941280.txt
# removing ./corpus/alignment/sentence_level_text/4065_941010_941280.txt
# ./corpus/alignment/sentence_level_text/4074_161030_162050.txt
# removing ./corpus/alignment/sentence_level_text/4074_161030_162050.txt
# ./corpus/alignment/sentence_level_text/0638_530730_531360.txt
# removing ./corpus/alignment/sentence_level_text/0638_530730_531360.txt
# ./corpus/alignment/sentence_level_text/0638_290390_290880.txt
# ./corpus/alignment/sentence_level_text/4074_423040_424110.txt
# removing ./corpus/alignment/sentence_level_text/4074_423040_424110.txt
# ./corpus/alignment/sentence_level_text/4065_545250_548020.txt
# ./corpus/alignment/sentence_level_text/0638_273990_274790.txt
# removing ./corpus/alignment/sentence_level_text/0638_273990_274790.txt
# ./corpus/alignment/sentence_level_text/0638_485650_486410.txt
# removing ./corpus/alignment/sentence_level_text/0638_485650_486410.txt
# ./corpus/alignment/sentence_level_text/4074_438960_439360.txt
# removing ./corpus/alignment/sentence_level_text/4074_438960_439360.txt
# ./corpus/alignment/sentence_level_text/0638_205780_206050.txt
# removing ./corpus/alignment/sentence_level_text/0638_205780_206050.txt
# ./corpus/alignment/sentence_level_text/4074_284800_286660.txt
# removing ./corpus/alignment/sentence_level_text/4074_284800_286660.txt
# ./corpus/alignment/sentence_level_text/4074_374141_378360.txt
# removing ./corpus/alignment/sentence_level_text/4074_374141_378360.txt
# ./corpus/alignment/sentence_level_text/4065_547430_552360.txt
# removing ./corpus/alignment/sentence_level_text/4065_547430_552360.txt
# ./corpus/alignment/sentence_level_text/4065_851380_852650.txt
# removing ./corpus/alignment/sentence_level_text/4065_851380_852650.txt
# ./corpus/alignment/sentence_level_text/4074_734320_736030.txt
# removing ./corpus/alignment/sentence_level_text/4074_734320_736030.txt
# ./corpus/alignment/sentence_level_text/4074_175710_176000.txt
# removing ./corpus/alignment/sentence_level_text/4074_175710_176000.txt
# ./corpus/alignment/sentence_level_text/0638_251290_251910.txt
# removing ./corpus/alignment/sentence_level_text/0638_251290_251910.txt
# ./corpus/alignment/sentence_level_text/0638_434060_434250.txt
# removing ./corpus/alignment/sentence_level_text/0638_434060_434250.txt
# ./corpus/alignment/sentence_level_text/0638_798150_798850.txt
# removing ./corpus/alignment/sentence_level_text/0638_798150_798850.txt
# ./corpus/alignment/sentence_level_text/4065_813880_814380.txt
# removing ./corpus/alignment/sentence_level_text/4065_813880_814380.txt
# ./corpus/alignment/sentence_level_text/4074_745630_747100.txt
# removing ./corpus/alignment/sentence_level_text/4074_745630_747100.txt
# ./corpus/alignment/sentence_level_text/4065_849620_850440.txt
# removing ./corpus/alignment/sentence_level_text/4065_849620_850440.txt
# ./corpus/alignment/sentence_level_text/0638_314870_315260.txt
# removing ./corpus/alignment/sentence_level_text/0638_314870_315260.txt
# ./corpus/alignment/sentence_level_text/0638_268780_269430.txt
# removing ./corpus/alignment/sentence_level_text/0638_268780_269430.txt
# ./corpus/alignment/sentence_level_text/4074_346530_351730.txt
# removing ./corpus/alignment/sentence_level_text/4074_346530_351730.txt
# ./corpus/alignment/sentence_level_text/0638_582870_583180.txt
# removing ./corpus/alignment/sentence_level_text/0638_582870_583180.txt
# ./corpus/alignment/sentence_level_text/0638_361480_363660.txt
# removing ./corpus/alignment/sentence_level_text/0638_361480_363660.txt
# ./corpus/alignment/sentence_level_text/4074_235270_236400.txt
# removing ./corpus/alignment/sentence_level_text/4074_235270_236400.txt
# ./corpus/alignment/sentence_level_text/0638_296180_296730.txt
# removing ./corpus/alignment/sentence_level_text/0638_296180_296730.txt
# ./corpus/alignment/sentence_level_text/0638_484600_485460.txt
# removing ./corpus/alignment/sentence_level_text/0638_484600_485460.txt
# ./corpus/alignment/sentence_level_text/4065_610150_612210.txt
# removing ./corpus/alignment/sentence_level_text/4065_610150_612210.txt
# ./corpus/alignment/sentence_level_text/4065_693730_694000.txt
# removing ./corpus/alignment/sentence_level_text/4065_693730_694000.txt
# ./corpus/alignment/sentence_level_text/4074_587910_588520.txt
# removing ./corpus/alignment/sentence_level_text/4074_587910_588520.txt
# ...
# ./corpus/alignment/sentence_level_text/0638_364000_364730.txt
# removing ./corpus/alignment/sentence_level_text/0638_364000_364730.txt
# ./corpus/alignment/sentence_level_text/4074_226010_229290.txt
# ./corpus/alignment/sentence_level_text/4074_309270_309620.txt
# removing ./corpus/alignment/sentence_level_text/4074_309270_309620.txt
# ./corpus/alignment/sentence_level_text/0638_632350_632710.txt
# ./corpus/alignment/sentence_level_text/4065_1030380_1030630.txt
# ./corpus/alignment/sentence_level_text/4065_836340_838150.txt
# removing ./corpus/alignment/sentence_level_text/4065_836340_838150.txt
# ./corpus/alignment/sentence_level_text/0638_593130_595350.txt
# removing ./corpus/alignment/sentence_level_text/0638_593130_595350.txt
# ./corpus/alignment/sentence_level_text/0638_563640_564210.txt
# removing ./corpus/alignment/sentence_level_text/0638_563640_564210.txt
# ./corpus/alignment/sentence_level_text/4074_623480_624710.txt
# removing ./corpus/alignment/sentence_level_text/4074_623480_624710.txt
# ./corpus/alignment/sentence_level_text/4065_1125310_1129350.txt
# removing ./corpus/alignment/sentence_level_text/4065_1125310_1129350.txt
# ./corpus/alignment/sentence_level_text/4065_895860_901490.txt
# removing ./corpus/alignment/sentence_level_text/4065_895860_901490.txt
# ./corpus/alignment/sentence_level_text/4065_972460_979470.txt
# ./corpus/alignment/sentence_level_text/4065_1058550_1064720.txt
# removing ./corpus/alignment/sentence_level_text/4065_1058550_1064720.txt
# ./corpus/alignment/sentence_level_text/0638_504850_506130.txt
# removing ./corpus/alignment/sentence_level_text/0638_504850_506130.txt
# ./corpus/alignment/sentence_level_text/4065_996510_997610.txt
# removing ./corpus/alignment/sentence_level_text/4065_996510_997610.txt
# ./corpus/alignment/sentence_level_text/0638_579590_580630.txt
# removing ./corpus/alignment/sentence_level_text/0638_579590_580630.txt
# ./corpus/alignment/sentence_level_text/4065_852880_855690.txt
# removing ./corpus/alignment/sentence_level_text/4065_852880_855690.txt
# ./corpus/alignment/sentence_level_text/0638_675210_675730.txt
# removing ./corpus/alignment/sentence_level_text/0638_675210_675730.txt
# ./corpus/alignment/sentence_level_text/4065_1006700_1009850.txt
# removing ./corpus/alignment/sentence_level_text/4065_1006700_1009850.txt
# ./corpus/alignment/sentence_level_text/0638_614080_616090.txt
# removing ./corpus/alignment/sentence_level_text/0638_614080_616090.txt
# ./corpus/alignment/sentence_level_text/4065_846100_846600.txt
# removing ./corpus/alignment/sentence_level_text/4065_846100_846600.txt
# ./corpus/alignment/sentence_level_text/4065_598990_599930.txt
# removing ./corpus/alignment/sentence_level_text/4065_598990_599930.txt
# ./corpus/alignment/sentence_level_text/0638_561170_562180.txt
# removing ./corpus/alignment/sentence_level_text/0638_561170_562180.txt
# ./corpus/alignment/sentence_level_text/4065_914191_916490.txt
# removing ./corpus/alignment/sentence_level_text/4065_914191_916490.txt
# ./corpus/alignment/sentence_level_text/4074_601580_601930.txt
# removing ./corpus/alignment/sentence_level_text/4074_601580_601930.txt
# ./corpus/alignment/sentence_level_text/4065_637150_641870.txt
# removing ./corpus/alignment/sentence_level_text/4065_637150_641870.txt
# ./corpus/alignment/sentence_level_text/0638_694970_696670.txt
# ./corpus/alignment/sentence_level_text/4065_842120_842640.txt
# ./corpus/alignment/sentence_level_text/0638_412960_413240.txt
# removing ./corpus/alignment/sentence_level_text/0638_412960_413240.txt
# ./corpus/alignment/sentence_level_text/0638_777860_780960.txt
# removing ./corpus/alignment/sentence_level_text/0638_777860_780960.txt
# ./corpus/alignment/sentence_level_text/0638_248870_249280.txt
# removing ./corpus/alignment/sentence_level_text/0638_248870_249280.txt
# ./corpus/alignment/sentence_level_text/4065_876990_880070.txt
# removing ./corpus/alignment/sentence_level_text/4065_876990_880070.txt
# ./corpus/alignment/sentence_level_text/4065_559950_562330.txt
# removing ./corpus/alignment/sentence_level_text/4065_559950_562330.txt
# ./corpus/alignment/sentence_level_text/0638_543850_543960.txt
# removing ./corpus/alignment/sentence_level_text/0638_543850_543960.txt
# ./corpus/alignment/sentence_level_text/0638_390710_392150.txt
# removing ./corpus/alignment/sentence_level_text/0638_390710_392150.txt
# ./corpus/alignment/sentence_level_text/4065_749210_749730.txt
# ./corpus/alignment/sentence_level_text/4065_1065310_1068920.txt
# ./corpus/alignment/sentence_level_text/4065_629230_629440.txt
# removing ./corpus/alignment/sentence_level_text/4065_629230_629440.txt
# ./corpus/alignment/sentence_level_text/0638_646670_648490.txt
# removing ./corpus/alignment/sentence_level_text/0638_646670_648490.txt
# ./corpus/alignment/sentence_level_text/4074_361980_363520.txt
# removing ./corpus/alignment/sentence_level_text/4074_361980_363520.txt
# ./corpus/alignment/sentence_level_text/4065_1130960_1133380.txt
# removing ./corpus/alignment/sentence_level_text/4065_1130960_1133380.txt
# ./corpus/alignment/sentence_level_text/0638_259620_259959.txt
# removing ./corpus/alignment/sentence_level_text/0638_259620_259959.txt
# ./corpus/alignment/sentence_level_text/4065_688790_691520.txt
# removing ./corpus/alignment/sentence_level_text/4065_688790_691520.txt
# ./corpus/alignment/sentence_level_text/0638_466850_471060.txt
# removing ./corpus/alignment/sentence_level_text/0638_466850_471060.txt
# ./corpus/alignment/sentence_level_text/0638_682070_682670.txt
# removing ./corpus/alignment/sentence_level_text/0638_682070_682670.txt
# ./corpus/alignment/sentence_level_text/0638_299410_300950.txt
# removing ./corpus/alignment/sentence_level_text/0638_299410_300950.txt
# ./corpus/alignment/sentence_level_text/0638_696120_697520.txt
# removing ./corpus/alignment/sentence_level_text/0638_696120_697520.txt
# ./corpus/alignment/sentence_level_text/0638_345810_346060.txt
# removing ./corpus/alignment/sentence_level_text/0638_345810_346060.txt
# ./corpus/alignment/sentence_level_text/4074_197940_198300.txt
# ./corpus/alignment/sentence_level_text/4074_698650_702350.txt
# removing ./corpus/alignment/sentence_level_text/4074_698650_702350.txt
# ./corpus/alignment/sentence_level_text/0638_411190_411300.txt
# removing ./corpus/alignment/sentence_level_text/0638_411190_411300.txt
# ./corpus/alignment/sentence_level_text/4065_655110_658360.txt
# removing ./corpus/alignment/sentence_level_text/4065_655110_658360.txt
# ./corpus/alignment/sentence_level_text/0638_667860_668310.txt
# removing ./corpus/alignment/sentence_level_text/0638_667860_668310.txt
# ./corpus/alignment/sentence_level_text/0638_509230_512250.txt
# removing ./corpus/alignment/sentence_level_text/0638_509230_512250.txt
# ./corpus/alignment/sentence_level_text/4074_287550_289210.txt
# removing ./corpus/alignment/sentence_level_text/4074_287550_289210.txt
# ./corpus/alignment/sentence_level_text/4065_1142710_1143070.txt
# removing ./corpus/alignment/sentence_level_text/4065_1142710_1143070.txt
# ./corpus/alignment/sentence_level_text/4065_1055570_1057780.txt
# removing ./corpus/alignment/sentence_level_text/4065_1055570_1057780.txt
# ./corpus/alignment/sentence_level_text/4074_723100_724060.txt
# removing ./corpus/alignment/sentence_level_text/4074_723100_724060.txt
# ./corpus/alignment/sentence_level_text/4065_563330_564740.txt
# removing ./corpus/alignment/sentence_level_text/4065_563330_564740.txt
# ./corpus/alignment/sentence_level_text/4074_188940_189300.txt
# ./corpus/alignment/sentence_level_text/4065_1106721_1112480.txt
# removing ./corpus/alignment/sentence_level_text/4065_1106721_1112480.txt
# ./corpus/alignment/sentence_level_text/0638_629840_631860.txt
# removing ./corpus/alignment/sentence_level_text/0638_629840_631860.txt
# ./corpus/alignment/sentence_level_text/4074_636000_639070.txt
# removing ./corpus/alignment/sentence_level_text/4074_636000_639070.txt
# ./corpus/alignment/sentence_level_text/0638_477110_477350.txt
# removing ./corpus/alignment/sentence_level_text/0638_477110_477350.txt
# ./corpus/alignment/sentence_level_text/4065_797900_798400.txt
# removing ./corpus/alignment/sentence_level_text/4065_797900_798400.txt
# ./corpus/alignment/sentence_level_text/0638_499000_499280.txt
# ./corpus/alignment/sentence_level_text/0638_210130_210500.txt
# ./corpus/alignment/sentence_level_text/4074_590630_595430.txt
# removing ./corpus/alignment/sentence_level_text/4074_590630_595430.txt
# ./corpus/alignment/sentence_level_text/0638_591700_592690.txt
# removing ./corpus/alignment/sentence_level_text/0638_591700_592690.txt
# ./corpus/alignment/sentence_level_text/0638_278470_279630.txt
# removing ./corpus/alignment/sentence_level_text/0638_278470_279630.txt
# ./corpus/alignment/sentence_level_text/4065_599180_600550.txt
# removing ./corpus/alignment/sentence_level_text/4065_599180_600550.txt
# ./corpus/alignment/sentence_level_text/4065_623160_627980.txt
# removing ./corpus/alignment/sentence_level_text/4065_623160_627980.txt
# ./corpus/alignment/sentence_level_text/4065_1050480_1052610.txt
# removing ./corpus/alignment/sentence_level_text/4065_1050480_1052610.txt
# ./corpus/alignment/sentence_level_text/4074_374140_374560.txt
# ./corpus/alignment/sentence_level_text/4065_642550_644660.txt
# removing ./corpus/alignment/sentence_level_text/4065_642550_644660.txt
# ./corpus/alignment/sentence_level_text/4074_752280_758880.txt
# removing ./corpus/alignment/sentence_level_text/4074_752280_758880.txt
# ./corpus/alignment/sentence_level_text/0638_742710_743100.txt
# removing ./corpus/alignment/sentence_level_text/0638_742710_743100.txt
# ./corpus/alignment/sentence_level_text/4074_688810_691880.txt
# removing ./corpus/alignment/sentence_level_text/4074_688810_691880.txt
# ./corpus/alignment/sentence_level_text/4065_616740_619760.txt
# removing ./corpus/alignment/sentence_level_text/4065_616740_619760.txt
# ./corpus/alignment/sentence_level_text/4074_737520_739590.txt
# removing ./corpus/alignment/sentence_level_text/4074_737520_739590.txt
# ./corpus/alignment/sentence_level_text/4074_368200_368960.txt
# removing ./corpus/alignment/sentence_level_text/4074_368200_368960.txt
# ./corpus/alignment/sentence_level_text/0638_528360_530270.txt
# removing ./corpus/alignment/sentence_level_text/0638_528360_530270.txt
# ./corpus/alignment/sentence_level_text/4074_236980_237360.txt
# removing ./corpus/alignment/sentence_level_text/4074_236980_237360.txt
# ./corpus/alignment/sentence_level_text/4065_856320_856760.txt
# removing ./corpus/alignment/sentence_level_text/4065_856320_856760.txt
# ./corpus/alignment/sentence_level_text/0638_228350_229280.txt
# removing ./corpus/alignment/sentence_level_text/0638_228350_229280.txt
# ./corpus/alignment/sentence_level_text/0638_261290_262650.txt
# removing ./corpus/alignment/sentence_level_text/0638_261290_262650.txt
# ./corpus/alignment/sentence_level_text/4074_628600_629600.txt
# removing ./corpus/alignment/sentence_level_text/4074_628600_629600.txt
# ./corpus/alignment/sentence_level_text/4074_692990_693720.txt
# ./corpus/alignment/sentence_level_text/0638_473780_474070.txt
# removing ./corpus/alignment/sentence_level_text/0638_473780_474070.txt
# ./corpus/alignment/sentence_level_text/4065_1121950_1122620.txt
# removing ./corpus/alignment/sentence_level_text/4065_1121950_1122620.txt
# ./corpus/alignment/sentence_level_text/4065_850630_851500.txt
# removing ./corpus/alignment/sentence_level_text/4065_850630_851500.txt
# ./corpus/alignment/sentence_level_text/4065_650580_654170.txt
# removing ./corpus/alignment/sentence_level_text/4065_650580_654170.txt
# ./corpus/alignment/sentence_level_text/0638_673620_674470.txt
# removing ./corpus/alignment/sentence_level_text/0638_673620_674470.txt
# ./corpus/alignment/sentence_level_text/4074_294700_299340.txt
# removing ./corpus/alignment/sentence_level_text/4074_294700_299340.txt
# ./corpus/alignment/sentence_level_text/4074_589920_590270.txt
# removing ./corpus/alignment/sentence_level_text/4074_589920_590270.txt
# ./corpus/alignment/sentence_level_text/0638_474570_474740.txt
# removing ./corpus/alignment/sentence_level_text/0638_474570_474740.txt
# ./corpus/alignment/sentence_level_text/4074_596540_598440.txt
# removing ./corpus/alignment/sentence_level_text/4074_596540_598440.txt
# ./corpus/alignment/sentence_level_text/0638_424160_424410.txt
# removing ./corpus/alignment/sentence_level_text/0638_424160_424410.txt
# ./corpus/alignment/sentence_level_text/0638_456650_456980.txt
# removing ./corpus/alignment/sentence_level_text/0638_456650_456980.txt
# ./corpus/alignment/sentence_level_text/0638_513190_514360.txt
# removing ./corpus/alignment/sentence_level_text/0638_513190_514360.txt
# ./corpus/alignment/sentence_level_text/4065_678820_679410.txt
# removing ./corpus/alignment/sentence_level_text/4065_678820_679410.txt
# ./corpus/alignment/sentence_level_text/0638_684350_684590.txt
# removing ./corpus/alignment/sentence_level_text/0638_684350_684590.txt
# ./corpus/alignment/sentence_level_text/4065_885851_895400.txt
# removing ./corpus/alignment/sentence_level_text/4065_885851_895400.txt
# ./corpus/alignment/sentence_level_text/4074_664170_668270.txt
# removing ./corpus/alignment/sentence_level_text/4074_664170_668270.txt
# ./corpus/alignment/sentence_level_text/4074_498610_498880.txt
# removing ./corpus/alignment/sentence_level_text/4074_498610_498880.txt
# ./corpus/alignment/sentence_level_text/4065_989420_991860.txt
# ./corpus/alignment/sentence_level_text/0638_286120_290160.txt
# ./corpus/alignment/sentence_level_text/4074_695850_696310.txt
# removing ./corpus/alignment/sentence_level_text/4074_695850_696310.txt
# ./corpus/alignment/sentence_level_text/4065_868520_876840.txt
# removing ./corpus/alignment/sentence_level_text/4065_868520_876840.txt
# ./corpus/alignment/sentence_level_text/0638_213050_215590.txt
# removing ./corpus/alignment/sentence_level_text/0638_213050_215590.txt
# ./corpus/alignment/sentence_level_text/0638_338370_338680.txt
# removing ./corpus/alignment/sentence_level_text/0638_338370_338680.txt
# ./corpus/alignment/sentence_level_text/4065_1067770_1069080.txt
# removing ./corpus/alignment/sentence_level_text/4065_1067770_1069080.txt
# ./corpus/alignment/sentence_level_text/0638_482870_484620.txt
# removing ./corpus/alignment/sentence_level_text/0638_482870_484620.txt
# ./corpus/alignment/sentence_level_text/0638_347980_350960.txt
# removing ./corpus/alignment/sentence_level_text/0638_347980_350960.txt
# ./corpus/alignment/sentence_level_text/4074_585880_587850.txt
# removing ./corpus/alignment/sentence_level_text/4074_585880_587850.txt
# ./corpus/alignment/sentence_level_text/0638_659780_660260.txt
# removing ./corpus/alignment/sentence_level_text/0638_659780_660260.txt
# ./corpus/alignment/sentence_level_text/0638_388380_388790.txt
# ./corpus/alignment/sentence_level_text/0638_723060_725530.txt
# removing ./corpus/alignment/sentence_level_text/0638_723060_725530.txt
# ./corpus/alignment/sentence_level_text/0638_326440_327000.txt
# ./corpus/alignment/sentence_level_text/0638_347210_347660.txt
# removing ./corpus/alignment/sentence_level_text/0638_347210_347660.txt
# ./corpus/alignment/sentence_level_text/0638_369710_369960.txt
# removing ./corpus/alignment/sentence_level_text/0638_369710_369960.txt
# ./corpus/alignment/sentence_level_text/4065_707960_710770.txt
# removing ./corpus/alignment/sentence_level_text/4065_707960_710770.txt
# ./corpus/alignment/sentence_level_text/0638_308160_309700.txt
# removing ./corpus/alignment/sentence_level_text/0638_308160_309700.txt
# ./corpus/alignment/sentence_level_text/0638_235990_236210.txt
# removing ./corpus/alignment/sentence_level_text/0638_235990_236210.txt
# ./corpus/alignment/sentence_level_text/0638_487750_487970.txt
# ./corpus/alignment/sentence_level_text/0638_270530_271290.txt
# removing ./corpus/alignment/sentence_level_text/0638_270530_271290.txt
# ./corpus/alignment/sentence_level_text/0638_319520_319630.txt
# removing ./corpus/alignment/sentence_level_text/0638_319520_319630.txt
# ./corpus/alignment/sentence_level_text/0638_545940_549800.txt
# removing ./corpus/alignment/sentence_level_text/0638_545940_549800.txt
# ./corpus/alignment/sentence_level_text/0638_521490_524950.txt
# removing ./corpus/alignment/sentence_level_text/0638_521490_524950.txt
# ./corpus/alignment/sentence_level_text/4065_693480_694860.txt
# removing ./corpus/alignment/sentence_level_text/4065_693480_694860.txt

# %% [markdown]
# # Word level alignment

# %%
# Converting the audio sentences into mono and resampling to 16kHz
path = './corpus/alignment/sentence_level_audio/'
for filename in listdir(path):
    if not filename.endswith('.wav'):
        continue
    try:
        sound = AudioSegment.from_wav(path+filename)
    except:
        breakpoint()
    sound = sound.set_channels(1)
    sound = sound.set_frame_rate(16000)
    sound.export(path+filename, format="wav")
    print(filename+' converted')

# %%
# Preparing the setup for MFA
# (converting .txt to .lab, and moving .lab and .wav sentence level into the same folder)

for filename in listdir('./corpus/alignment/sentence_level_audio'):
    _id = filename.split('.')[0]
    system('mv ./corpus/alignment/sentence_level_audio/{}.wav ./corpus/alignment/mfa_setup/{}.wav '.format(_id,_id))
    system('mv ./corpus/alignment/sentence_level_text/{}.txt ./corpus/alignment/mfa_setup/{}.lab'.format(_id,_id))

# %%
mfa_path = '/Users/thibo/Downloads/montreal-forced-aligner/' # Replace with the installation directory of Montreal Forced Aligner
lm_path = './corpus/alignment/librispeech-lexicon.txt' # Language model
lab_wav_path = './corpus/alignment/mfa_setup/' # Input folder
output_path = './corpus/alignment/textgrids/' # Output folder

# %%
# mfa command
system('{}/bin/mfa_align -v {} {} english {} '.format(mfa_path, lab_wav_path, lm_path, output_path))
# Out:
# /Users/thibo/Downloads/montreal-forced-aligner//bin/mfa_align -v ./corpus/alignment/mfa_setup/ ./corpus/alignment/librispeech-lexicon.txt english ./corpus/alignment/textgrids/

# %% [markdown]
# # Data preparation

# %%
import textgrids as tg
import pandas as pd

# %%
hesitations = [
    'mhm',
    'uhhuh',
    'mm',
    'um',
    'eh',
    'em',
    'ah',
    'huh',
    'ha',
    'er',
    'oof',
    'hee',
    'ach',
    'eee',
    'ew'
]

silence = ['sp', 'sil','']

def tag_word(word):
    if word in hesitations: 
        return 'hesitation'
    elif word in silence:
        return 'silence'
    else:
        return 'speech'

# %% [markdown]
# **You can jump until the end if you have the pickles**

# %%
words_df = pd.DataFrame(columns=['file','word','tag','xmin','xmax'])
files_df = pd.DataFrame(columns=['file', 'xmin','xmax'])

# %%
for filename in listdir('./corpus/alignment/textgrids'):
    if not filename.endswith('.TextGrid'):
        continue
    name = filename.split('.')[0]
    the_tg = tg.TextGrid('./corpus/alignment/textgrids/'+filename)
    
    # Filling the dataframe of files
    files_df.loc[len(files_df)] = {'file':name,
                            'xmin':the_tg.xmin,
                            'xmax':the_tg.xmax}
    
    # Filling the dataframe of words 
    for word in the_tg['words']:
        words_df.loc[len(words_df)] = {'file':name,
                             'word':word.text,
                             'tag':tag_word(word.text),
                             'xmin':word.xmin,
                             'xmax':word.xmax
                            }

# %% [markdown]
# ## Words dataframe

# %%
words_df.head()

# %%
words_df['duration'] = words_df['xmax']-words_df['xmin']

# %%
words_df['duration'].plot.box()

# %%
# converting to ms
words_df['xmin'] = words_df['xmin'].apply(lambda x: int(x*1000))
words_df['xmax'] = words_df['xmax'].apply(lambda x: int(x*1000))
words_df['duration'] = words_df['duration'].apply(lambda x: int(x*1000))

# %%
words_df.groupby('tag').count().file

# %% [markdown]
# ## Files dataframe

# %%
files_df.head()

# %%
files_df['duration'] = files_df['xmax']-files_df['xmin']

# %%
# converting to ms
files_df['xmin'] = files_df['xmin'].apply(lambda x: int(x*1000))
files_df['xmax'] = files_df['xmax'].apply(lambda x: int(x*1000))
files_df['duration'] = files_df['duration'].apply(lambda x: int(x*1000))

# %% [markdown]
# ## Saving

# %%
words_df.to_pickle('./pickles/words_df.pkl')
files_df.to_pickle('./pickles/files_df.pkl')

# %% [markdown]
# ## Loading

# %%
words_df = pd.read_pickle('./pickles/words_df.pkl')
files_df = pd.read_pickle('./pickles/files_df.pkl')

# %% [markdown]
# # Framing audios

# %%
import torch

# %%
def tag_decision_med(filename, xmin, xmax):
    # Taking the median sample
    med = int((xmin+xmax)/2)
    query = words_df.query("file=='{}' and {} >= xmin and {} <= xmax ".format(filename, med, med))
    tag = query.iloc[0]['tag']
    return tag

# %%
tag2int = {
    '<dummy>':0,
    'speech':1,
    'silence':2,
    'hesitation':3
}

# %%
sampling_rate = 16000
win_shift = 12.5
win_len = 12.5
numb_files = len(files_df)
max_len = int(files_df['duration'].max() // win_len)

# %% [markdown]
# **Skip the following if you have tags.pt**

# %%
Y = torch.zeros((numb_files,max_len))

# %%
i,j = 0,0

for audiofile in files_df['file']:
    j = 0
    filename = audiofile
    file_df = files_df.query("file == '{}'".format(filename))
    duration = file_df.iloc[0]['duration']
    head = 0
    while head + win_shift <= duration:
        try:
            tag = tag2int[tag_decision_med(filename, head, head+win_len )]
            Y[i][j] = tag
        except:
            continue
        head += win_shift
        j += 1
    i += 1
    print('{} / {}'.format(i,numb_files))

# %%
print(Y.shape)

# %%
print(Y)

# %%
torch.unique(Y, return_counts = True)

# %% [markdown]
# ## Saving

# %%
torch.save(tags,'./pickles/Y.pt')

# %% [markdown]
# ## Loading

# %%
Y = torch.load('./pickles/Y.pt')

# %% [markdown]
# # MFCC Extraction

# %%
import torchaudio

# %%
mfcc_tensors = []

for audiofile in files_df['file']:
    waveform, sample_rate = torchaudio.load('./corpus/alignment/mfa_setup/'+audiofile+'.wav')
    mfcc = torchaudio.transforms.MFCC(n_mfcc=13)(waveform)
    torch.set_printoptions(sci_mode=False)
    mfcc_tensors.append(mfcc)

# %%
padded_tensors = []

for tensor in mfcc_tensors:
    target = torch.zeros(1, 13, max_len+1)
    source = tensor
    target[:, :, :tensor.shape[2]] = source
    padded_tensors.append(target)

# %%
X = torch.cat((padded_tensors), dim=0)

# %%
X.shape

# %%
X = torch.narrow(X, 2, 0, max_len)

# %%
X.shape

# %%
Y.shape

# %%
Y = Y.unsqueeze(1)

# %%
Y.shape

# %% [markdown]
# ## Saving

# %%
torch.save(X,'./pickles/X.pt')
torch.save(Y,'./pickles/Y.pt')

# %% [markdown]
# ## Loading

# %%
X = torch.load('./pickles/X.pt')
Y = torch.load('./pickles/Y.pt')

# %% [markdown]
# # RNN Tagging

# %%
from torch.utils.data import TensorDataset, DataLoader
from torch import nn
import torch.optim as optim
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split

# %%
X = torch.load('./pickles/X.pt')
Y = torch.load('./pickles/Y.pt').squeeze(1)

# %%
print(X.shape)
print(Y.shape)

# %%
BATCH_SIZE = 32
N_STEPS = X.shape[2]
N_INPUTS = 13
N_NEURONS = 150
N_OUTPUTS = 4
N_EPHOCS = 50
LR = 0.05

# %%
X_train, X_valid, Y_train, Y_valid = train_test_split(X, Y, test_size=0.20, random_state=42)

train_set = TensorDataset(X_train, Y_train)
valid_set = TensorDataset(X_valid, Y_valid)

train_loader = DataLoader(train_set, batch_size=BATCH_SIZE, shuffle=True)
valid_loader = DataLoader(valid_set, batch_size=BATCH_SIZE)

# %%
class RNN(nn.Module):
    def __init__(self, batch_size, n_steps, n_inputs, n_neurons, n_outputs):
        super(RNN, self).__init__()
        
        self.n_neurons = n_neurons
        self.batch_size = batch_size
        self.n_steps = n_steps
        self.n_inputs = n_inputs
        self.n_outputs = n_outputs
        
        self.basic_rnn = nn.RNN(self.n_inputs, self.n_neurons)
        
        self.FC = nn.Linear(self.n_neurons, self.n_outputs)
        
    def init_hidden(self,):
        # (num_layers, batch_size, n_neurons)
        return (torch.zeros(1, self.batch_size, self.n_neurons))
        
    def forward(self, X):
        # transforms X to dimensions: n_steps X batch_size X n_inputs
        X = X.permute(1, 0, 2)

        self.batch_size = X.size(1)
        self.hidden = self.init_hidden()

        lstm_out, self.hidden = self.basic_rnn(X, self.hidden)
        out = self.FC(lstm_out)

        return out.view(-1, self.n_outputs) # batch_size X n_output

# %%
# Device
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# Model instance
model = RNN(BATCH_SIZE, N_STEPS, N_INPUTS, N_NEURONS, N_OUTPUTS)
criterion = nn.CrossEntropyLoss(size_average=True, ignore_index=0)
optimizer = optim.Adam(model.parameters(), lr=LR)

def get_accuracy(logit, target, batch_size):
    ''' Obtain accuracy for training round '''
    corrects = (torch.max(logit, 1)[1].view(target.size()).data == target.data).sum()
    accuracy = 100 * corrects/batch_size
    return accuracy.item()

# %%
for epoch in range(N_EPHOCS):  # loop over the dataset multiple times
    train_running_loss = 0.0
    train_acc = 0.0
    outs = []
    golds = []
    model.train()
    
    # TRAINING ROUND
    for i, data in enumerate(train_loader):
         # zero the parameter gradients
        optimizer.zero_grad()
        
        # reset hidden states
        model.hidden = model.init_hidden() 
        
        # get the inputs
        inputs, labels = data
        inputs = inputs.view(-1, N_STEPS, N_INPUTS)

        # forward + backward + optimize
        outputs = model(inputs)

        loss = criterion(outputs, labels.long().view(-1))
        
        loss.backward()
        optimizer.step()

        train_running_loss += loss.detach().item()
        train_acc += get_accuracy(outputs, labels.long().view(-1), BATCH_SIZE)
        
        out = torch.max(outputs, 1)[1].view(labels.long().view(-1).size()).data
        gold = labels.long().view(-1).data
        outs.append(out)
        golds.append(gold)
         
    model.eval()
    print('Epoch:  %d | Loss: %.4f | Train Accuracy: %.2f' 
          %(epoch+1, train_running_loss/i, train_acc/(i*N_STEPS)))
    
    y_pred = torch.cat(outs)
    y_gold = torch.cat(golds)

    print(confusion_matrix(y_gold, y_pred, labels=[1, 2, 3]))
    print(classification_report(y_gold, y_pred, labels=[1, 2, 3]))

# %%
test_acc = 0.0
outs = []
golds = []

for i, data in enumerate(valid_loader, 0):
    inputs, labels = data
    inputs = inputs.view(-1, N_STEPS, N_INPUTS)

    outputs = model(inputs)

    test_acc += get_accuracy(outputs, labels.long().view(-1), BATCH_SIZE)
    out = torch.max(outputs, 1)[1].view(labels.long().view(-1).size()).data
    gold = labels.long().view(-1).data
    outs.append(out)
    golds.append(gold)
        
print('Test Accuracy: %.2f'%(test_acc/(i*N_STEPS)))

y_pred = torch.cat(outs)
y_gold = torch.cat(golds)

print(confusion_matrix(y_gold, y_pred, labels=[1, 2, 3]))
print(classification_report(y_gold, y_pred, labels=[1, 2, 3]))

# %%
cm1 = pd.DataFrame({'speech':[307140,673,894],'silence':[67293,146,147],'filler':[77599,198,292]}, index=["speech", "silence", "filler"])
matrix = sns.heatmap(cm1.T, annot=True, fmt='d', linewidths=.5, cmap='coolwarm')
matrix.set(xlabel='predicted label', ylabel='true label')

# %%
cm = pd.DataFrame({'speech':[38602,0,0],'silence':[8888,0,0],'filler':[11674,0,0]}, index=["speech", "silence", "filler"])
matrix = sns.heatmap(cm.T, annot=True, fmt='d', linewidths=.5, cmap='coolwarm')
matrix.set(xlabel='predicted label', ylabel='true label')
